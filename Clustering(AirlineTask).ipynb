# %% [markdown]
# # Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters.
# Draw the inferences from the clusters obtained.

# %% [markdown]
# # Hierarchical Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
data=pd.read_excel('E:\\Assisgnments\\Clustering\\EastWestAirlines.xlsx',sheet_name='data')

# %%
data.head(5)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.drop(['ID#'],axis=1,inplace=True)
data.head(5)
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
# Normalize heterogenous numerical data using z-score (x-mean/std) or custom defined function 
# Normalization function - here custom defined
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
data_norm = norm_func(data)
data_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
plt.figure(figsize=(10, 7))  
dendograms=sch.dendrogram(sch.linkage(data_norm,'complete'))

# %%
hclusters=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hclusters
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
y=pd.DataFrame(hclusters.fit_predict(data_norm),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# 1    1011
# 0     946
# 2     808
# 4     699
# 3     535
# Name: clustersid, dtype: int64

# %%
data['clustersid']=hclusters.labels_
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
data.groupby('clustersid').agg(['mean']).reset_index()
# Out:
#   clustersid        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# 0          0   79848.233615  285.097252  1.699789  1.024313  1.000000
# 1          1   43313.653808   21.506429  1.000000  1.033630  1.000989
# 2          2  106221.111386  161.262376  3.198020  1.001238  1.025990
# 3          3  127475.028037  160.801869  4.362617  1.000000  1.050467
# 4          4   30013.416309   98.054363  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  12079.774841   12.133192        781.939746        2.369979
# 1   2562.614243    5.474777        169.510386        0.523244
# 2  26458.257426   16.363861        198.733911        0.558168
# 3  58656.919626   22.235514        991.110280        3.005607
# 4   2552.569385    6.101574        340.274678        0.948498
#
#   Days_since_enroll Award?
# ...

# %%
plt.figure(figsize=(10, 6))  
plt.scatter(data['clustersid'],data['Balance'], c=hclusters.labels_)

# %% [markdown]
# # K-means Clustering

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# %%
data1=pd.read_excel('E:/Assisgnments/Clustering/EastWestAirlines.xlsx',sheet_name='data')

# %%
data1.head(5)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
data_norm = norm_func(data1)
data_norm
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
model = KMeans(n_clusters=5)
model.fit(data_norm)
# Out:
# KMeans(n_clusters=5)

# %%
model.labels_
# Out:
# array([0, 0, 0, ..., 1, 3, 3])

# %%
md = pd.Series(model.labels_)

# %%
data1['clusters'] = md 
data1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data1.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean           mean        mean      mean      mean
# 0        0  1169.978009   49674.980324   90.319444  1.118056  1.017361
# 1        1  2063.952020   78078.890152  274.411616  1.433081  1.027778
# 2        2  1628.158379  125899.655617   68.941068  3.664825  1.001842
# 3        3  3219.702070   35385.638164   94.610261  1.204320  1.017102
# 4        4  1379.641509  118863.698113  200.866473  4.074020  1.001451
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.001157   3386.160880    6.824074        242.075231        0.719907
# 1  1.007576  10703.342172   11.363636        924.084596        2.804293
# 2  1.025783  33035.488029   17.337017        225.740331        0.655617
# 3  1.006301   4400.907291    6.941494        214.288029        0.598560
# ...

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data1['clusters'],data1['Balance'], c=model.labels_)

# %% [markdown]
# # DBSCAN Clustering

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN

# %%
data1=pd.read_excel('E:/Assisgnments/Clustering/EastWestAirlines.xlsx',sheet_name='data')

# %%
data1.head(5)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data1.drop(['ID#'],axis=1,inplace=True)
data1.head(5)
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
data_norm = norm_func(data1)
data_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
dbscan = DBSCAN(eps=0.8, min_samples=15)
dbscan.fit(data_norm)
# Out:
# DBSCAN(eps=0.8, min_samples=15)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
data['clusters']=dbscan.labels_
data.head(5)
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    clusters
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
data.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                     mean        mean      mean      mean      mean
# 0        0  59807.839555   87.602462  1.705322   1.01390  1.008737
# 1        1  97053.051317  240.196489  2.661715   1.01553  1.018231
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  10227.689039    9.142971        226.292295        0.652502
# 1  28905.414585   15.782579        857.501013        2.599595
#
#   Days_since_enroll Award?
#                mean   mean
# 0       3820.652105      0
# 1       4625.062120      1

# %%
# Plot Clusters
plt.figure(figsize=(10,6))
plt.scatter(data['clusters'],data['Balance'],c=dbscan.labels_)
